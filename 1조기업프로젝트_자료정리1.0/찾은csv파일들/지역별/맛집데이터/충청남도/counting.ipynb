# %%
import pandas as pd

# CSV 파일을 읽어옵니다.
df = pd.read_csv('천안시.csv')

# 순위 컬럼의 데이터를 삭제합니다.
df.drop('순위', axis=1, inplace=True)

# 현지인 검색 수 기준으로 순위를 다시 매깁니다.
df['순위'] = df['현지인 검색 수'].rank(ascending=False, method='min').astype(int)

# 순위 컬럼을 가장 앞으로 이동합니다.
cols = list(df.columns)
cols.remove('순위')
cols.insert(0, '순위')
cols.remove('순위.1')
df = df[cols]

# 중복된 순위 컬럼을 삭제합니다.
df = df.loc[:, ~df.columns.duplicated()]

# 순위를 내림차순으로 정렬합니다.
df.sort_values(by='순위', ascending=True, inplace=True)

# 수정된 데이터프레임을 CSV 파일로 저장합니다.
df.to_csv('천안시.csv', index=False)

# 저장 완료 메시지를 출력합니다.
print("데이터가 천안시.csv로 저장되었습니다.")
# Out:
# 데이터가 천안시.csv로 저장되었습니다.

# %%
pd.DataFrame(df)
# Out:
#       순위          업소명                      주소     분류  현지인 검색 수
# 199    1  맥도날드천안두정DT점    충남 천안시 서북구 동서대로 49-0   간이음식     20405
# 198    2       병천순대거리  충남 천안시 동남구 아우내순대길 33-0  음식점기타     15655
# 197    3     뚜쥬루빵돌가마점    충남 천안시 동남구 풍세로 706-0   간이음식     15569
# 196    4      두정동먹자골목   충남 천안시 서북구 원두정2길 15-0  음식점기타     12581
# 195    5       뚜쥬루성정점    충남 천안시 서북구 백석로 270-0   간이음식     11679
# ..   ...          ...                     ...    ...       ...
# 4    196    삼쿡시대청수지구점   충남 천안시 동남구 청수13로 16-0     한식      1001
# 3    197     광화문집[한식]   충남 천안시 동남구 원성2교길 49-0     한식       995
# 2    198           들꽃   충남 천안시 동남구 호서대길 110-0     한식       994
# 1    199      아우내장터순대  충남 천안시 동남구 아우내순대길 40-0     한식       988
# 0    200           앙프  충남 천안시 동남구 천안천변길 139-0  카페/찻집       986
#
# [200 rows x 5 columns]
