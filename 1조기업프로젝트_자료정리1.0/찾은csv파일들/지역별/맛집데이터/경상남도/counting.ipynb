# %%
import pandas as pd

# CSV 파일을 읽어옵니다.
df = pd.read_csv('창원시.csv')

# 순위 컬럼의 데이터를 삭제합니다.
df.drop('순위', axis=1, inplace=True)

# 현지인 검색 수 기준으로 순위를 다시 매깁니다.
df['순위'] = df['현지인 검색 수'].rank(ascending=False, method='min').astype(int)

# 순위 컬럼을 가장 앞으로 이동합니다.
cols = list(df.columns)
cols.remove('순위')
cols.insert(0, '순위')
# cols.remove('순위.1')
df = df[cols]

# 중복된 순위 컬럼을 삭제합니다.
df = df.loc[:, ~df.columns.duplicated()]

# 순위를 내림차순으로 정렬합니다.
df.sort_values(by='순위', ascending=True, inplace=True)

# 수정된 데이터프레임을 CSV 파일로 저장합니다.
df.to_csv('창원시.csv', index=False)

# 저장 완료 메시지를 출력합니다.
print("데이터가 창원시.csv로 저장되었습니다.")
# Out:
# 데이터가 창원시.csv로 저장되었습니다.

# %%
pd.DataFrame(df)
# Out:
#       순위            업소명                         주소     분류  현지인 검색 수
# 200    1  아웃백스테이크하우스중앙점       경남 창원시 성산구 중앙대로 33-0   전문음식     15360
# 201    2    투썸플레이스창원귀산점       경남 창원시 성산구 삼귀로 167-0  카페/찻집     14944
# 202    3    맥도날드창원사파DT점   경남 창원시 성산구 창이대로706번길 2-0   간이음식      8413
# 203    4    스타벅스창원마창대교점       경남 창원시 성산구 삼귀로 159-0  카페/찻집      6665
# 204    5    맥도날드창원시티세븐점      경남 창원시 성산구 원이대로 320-0   간이음식      6536
# ..   ...            ...                        ...    ...       ...
# 195  495           샤브미경     경남 창원시 마산회원구 양덕로 115-0    외국식        79
# 196  495     이디야커피마산삼계점      경남 창원시 마산회원구 삼계로 45-1  카페/찻집        79
# 197  498          미담정국수     경남 창원시 마산회원구 북성로 516-0     한식        77
# 198  499        호계리치프라자     경남 창원시 마산회원구 호원로 311-0  음식점기타        76
# 199  500   뚜레쥬르마산합성터미널점  경남 창원시 마산회원구 3·15대로 745-0   간이음식        74
#
# [500 rows x 5 columns]
